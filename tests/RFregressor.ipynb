# %%
# !git clone https://github.com/quark28/miniml.git
# %cd miniml
# Out:
# Cloning into 'miniml'...
# remote: Enumerating objects: 327, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 327 (delta 79), reused 81 (delta 41), pack-reused 204 (from 1)
# Receiving objects: 100% (327/327), 2.29 MiB | 19.85 MiB/s, done.
# Resolving deltas: 100% (174/174), done.
# /content/miniml

# %%
from miniml.tree_based.randomforestregressor import RandomForestRegression
from miniml.tree_based.decisiontreeregressor import DecisionTreeRegression

# %%
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor as SKRF
from sklearn.datasets import make_regression


X, y = make_regression(
    n_samples=2000,
    n_features=30,
    n_informative=10,
    noise=20,
    random_state=42
)


X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=42
)


custom_rf = RandomForestRegression(
    n_estimators=100,
    max_depth=10,
    max_features='sqrt',
    random_state=42
)


sk_rf = SKRF(
    n_estimators=100,
    max_depth=10,
    max_features='sqrt',
    random_state=42
)


custom_rf.fit(X_train, y_train)
sk_rf.fit(X_train, y_train)


pred_custom = custom_rf.predict(X_test)
pred_sk = sk_rf.predict(X_test)


print("="*60)
print("RANDOM FOREST COMPARISON")
print("="*60)

print(
    "Custom MSE:",
    mean_squared_error(y_test, pred_custom)
)

print(
    "Sklearn MSE:",
    mean_squared_error(y_test, pred_sk)
)

print(
    "MAE predictions difference:",
    np.mean(abs(pred_custom-pred_sk))
)
# Out:
# ...
# RANDOM FOREST COMPARISON
# ...
# Custom MSE: 14366.988182561248
# Sklearn MSE: 13543.190943779573
# MAE predictions difference: 17.575532480210914
